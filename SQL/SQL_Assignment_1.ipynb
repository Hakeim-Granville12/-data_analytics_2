# %% [markdown]
# # Hakeim Granville
# # SQL Assignment 1

# %%
select * from customer limit 10;

# %% [markdown]
# ![Capture 1.PNG](data:image/png;base64,...)

# %%
select first_name, last_name, email from customer limit 10;

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
select * from film limit 10 ;

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
select distinct  release_year from film;

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
select distinct rental_rate from film;

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
select email from customer where first_name = 'Nancy' and last_name = 'Thomas';

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
select * from customer where store_id = 1 and address_id >= 150 limit 15;

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
select * from payment where amount = 1.99 or amount = 4.99 limit 15;

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
select * from payment  where amount >= 5 limit 10 ;

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
select phone from address where address = '259 Ipoh Drive';

# %% [markdown]
# ![image.png](data:image/png;base64,...)
