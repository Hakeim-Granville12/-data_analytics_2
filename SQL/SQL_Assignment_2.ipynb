# %% [markdown]
# # Hakeim Granville
#
# # SQL Assignment 2

# %%
SELECT film.film_id, film.title, film.description, 
film.release_year, film.language_id, film.rental_duration, 
film.rental_rate, film.length, film.replacement_cost,
film.rating, film.last_update, film.special_features,
film.fulltext, actor_id
FROM film
FULL JOIN film_actor 
ON film.film_id = film_actor.film_id limit 15;

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
SELECT Distinct actor.actor_id, actor.first_name, actor.last_name, film_actor.film_id 
FROM actor
full JOIN film_actor
ON actor.actor_id = film_actor.actor_id limit 10 ;

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
select actor.actor_id, actor.first_name, actor.last_name, actor.last_update, film_actor.film_id, film.title, film.description, 
film.release_year, film.language_id, film.rental_duration 
FROM film, film_actor, actor
where actor.actor_id = film_actor.actor_id
and film.film_id = film_actor.film_id
group by actor.actor_id, actor.first_name, actor.last_name, actor.last_update, film_actor.film_id, film.title, film.description, 
film.release_year, film.language_id, film.rental_duration
order by actor.first_name limit 15;

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
SELECT DISTINCT first_name,student.last_name, student_marks.unit4 
FROM student, student_marks
WHERE unit4 = 100 limit 10;

# %% [markdown]
# # ![image.png](data:image/png;base64,...)

# %%
select distinct first_name,student.last_name, student_marks.unit4 
from student, student_marks
where unit4 between 89 and 100 limit 10;

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# How many students got between 50 and 75 on unit 1?
#
# What is the median score?
#
# Which gender scored the highest in all units?
#
# Whuch student scored the highest on all units?
#
# what is the average of students that use hard copy books?
